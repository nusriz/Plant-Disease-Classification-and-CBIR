# %% [markdown]
# All the features considered for classification should be of same dimension. 533x800 seems standard. This is a driver code for image resize

# %%
import os
import cv2

#include google drive path for image input
path = ''


dim = (533,800)
im)
j=0
for i in os.listdir(path):
	j=j+1
	img = cv2.imread(os.path.join(path,i))
	resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
  #Format for saving resized image at output location
	temp = 'Sep'+str(j)+'.png'
	cv2.imwrite(os.path.join(path,temp),resized)
